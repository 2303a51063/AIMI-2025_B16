# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51063/AIMI-2025_B16/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
list=[1,2,3]
array1=np.array(list)
array1
# Out:
# array([1, 2, 3])

# %%
type(list)
# Out:
# list

# %%
type(array)
# Out:
# numpy.ndarray

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1 : ",array1*array2)
print("array2 divided by array1 : ",array1/array2)
print("array2 added to array1 : ",array1+array2)
print("array2 subtracted from array1 : ",array1-array2)
print("array1 to the power of array2 : ",array1**array2)
print(f"{array2} raised to the power of {array1}: ,  {array2**array1} ")
# Out:
# array2 multiplied by array1 :  [3 4 3]
# array2 divided by array1 :  [0.33333333 1.         3.        ]
# array2 added to array1 :  [4 4 4]
# array2 subtracted from array1 :  [-2  0  2]
# array1 to the power of array2 :  [1 4 3]
# [3 2 1] raised to the power of [1 2 3]: ,  [3 4 1]

# %%
people=['Ann','Brandon','chen','David','emily','farook','Gagan','hamish','Imran','Julio','katherine','Lily']
age=[21,12,32,45,37,18,28,52,5,40,48,15]
weight=[55,35,77,68,70,60,72,69,18,65,82,48]
height=[160,135,170,165,173,168,175,159,105,171,155,158]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight in Kilograms")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,fontstyle='italic')
# main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='black',edgecolor='k',alpha=0.6) # Changed 'colour' to 'color'
plt.xlabel("People",fontsize=15)
plt.ylabel("Weight in Kgs",fontsize=15)
plt.show()

# %%
import numpy as np

plt.figure(figsize=(7,5))

#Main plot function 'hist"

plt.hist(weight, color='black', edgecolor='k', alpha=0.75, bins=5)

plt.title("Histogram of patient weight", fontsize=18)

plt.xlabel("Weight in kgs", fontsize=15)

#plt.xticks(fontsize=15)

#plt.yticks(fontsize=15)

plt.show()
